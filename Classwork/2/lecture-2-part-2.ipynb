# %%
import pandas as pd
import numpy as np

from tqdm.notebook import tqdm

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.neighbors import NearestNeighbors

# %matplotlib inline

# %%
links = pd.read_csv(r'C:\Users\pc\PycharmProjects\Netology\Classwork\data\links.csv')
movies = pd.read_csv(r'C:\Users\pc\PycharmProjects\Netology\Classwork\data\movies.csv')
ratings = pd.read_csv(r'C:\Users\pc\PycharmProjects\Netology\Classwork\data\ratings.csv')
tags = pd.read_csv(r'C:\Users\pc\PycharmProjects\Netology\Classwork\data\tags.csv')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# 8                                       Action
# 9                    Action|Adventure|Thriller

# %%
def change_string(s):
    return ' '.join(s.replace(' ', '').replace('-', '').split('|'))

# %%
movie_genres = [change_string(g) for g in movies.genres.values]

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(movie_genres)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
neigh = NearestNeighbors(n_neighbors=7, n_jobs=-1, metric='euclidean') 
neigh.fit(X_train_tfidf)
# Out:
# NearestNeighbors(metric='euclidean', n_jobs=-1, n_neighbors=7)

# %%
test = change_string("Adventure|Comedy|Fantasy|Crime")

predict = count_vect.transform([test])
X_tfidf2 = tfidf_transformer.transform(predict)

res = neigh.kneighbors(X_tfidf2, return_distance=True)

# %%
res
# Out:
# (array([[0.42079615, 0.53300564, 0.54288608, 0.54288608, 0.54288608,
#          0.54288608, 0.54288608]]),
#  array([[6774, 9096, 5636, 6723, 3376, 7496, 9717]], dtype=int32))

# %%
movies.iloc[res[1][0]]
# Out:
#       movieId                                              title  \
# 6774    60074                                     Hancock (2008)
# 9096   143559                                L.A. Slasher (2015)
# 5636    27368  Asterix & Obelix: Mission Cleopatra (Astérix &...
# 6723    58972                                Nim's Island (2008)
# 3376     4591                             Erik the Viking (1989)
# 7496    82854                          Gulliver's Travels (2010)
# 9717   188833              The Man Who Killed Don Quixote (2018)
#
#                                      genres
# 6774  Action|Adventure|Comedy|Crime|Fantasy
# 9096                   Comedy|Crime|Fantasy
# 5636               Adventure|Comedy|Fantasy
# 6723               Adventure|Comedy|Fantasy
# 3376               Adventure|Comedy|Fantasy
# 7496               Adventure|Comedy|Fantasy
# 9717               Adventure|Comedy|Fantasy

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
movies_with_tags = movies.join(tags.set_index('movieId'), on='movieId')

# %%
movies_with_tags.head()
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#    userId               tag     timestamp
# 0   336.0             pixar  1.139046e+09
# 0   474.0             pixar  1.137207e+09
# 0   567.0               fun  1.525286e+09
# 1    62.0           fantasy  1.528844e+09
# 1    62.0  magic board game  1.528844e+09

# %%
movies_with_tags[movies_with_tags.title == 'Toy Story (1995)']
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
#
#    userId    tag     timestamp
# 0   336.0  pixar  1.139046e+09
# 0   474.0  pixar  1.137207e+09
# 0   567.0    fun  1.525286e+09

# %%
movies_with_tags.tag.unique()
# Out:
# array(['pixar', 'fun', 'fantasy', ..., 'star wars', 'gintama', 'remaster'],
#       dtype=object)

# %%
movies_with_tags.tag.unique().shape
# Out:
# (1590,)

# %%
movies_with_tags.dropna(inplace=True)

# %%
movies_with_tags.groupby('title').head()
# Out:
#       movieId                           title  \
# 0           1                Toy Story (1995)
# 0           1                Toy Story (1995)
# 0           1                Toy Story (1995)
# 1           2                  Jumanji (1995)
# 1           2                  Jumanji (1995)
# ...       ...                             ...
# 9710   187595  Solo: A Star Wars Story (2018)
# 9732   193565       Gintama: The Movie (2010)
# 9732   193565       Gintama: The Movie (2010)
# 9732   193565       Gintama: The Movie (2010)
# 9732   193565       Gintama: The Movie (2010)
#
#                                            genres  userId               tag  \
# 0     Adventure|Animation|Children|Comedy|Fantasy   336.0             pixar
# 0     Adventure|Animation|Children|Comedy|Fantasy   474.0             pixar
# 0     Adventure|Animation|Children|Comedy|Fantasy   567.0               fun
# 1                      Adventure|Children|Fantasy    62.0           fantasy
# 1                      Adventure|Children|Fantasy    62.0  magic board game
# ...                                           ...     ...               ...
# 9710             Action|Adventure|Children|Sci-Fi    62.0         star wars
# 9732               Action|Animation|Comedy|Sci-Fi   184.0             anime
# 9732               Action|Animation|Comedy|Sci-Fi   184.0            comedy
# 9732               Action|Animation|Comedy|Sci-Fi   184.0           gintama
# 9732               Action|Animation|Comedy|Sci-Fi   184.0          remaster
#
#          timestamp
# 0     1.139046e+09
# 0     1.137207e+09
# 0     1.525286e+09
# 1     1.528844e+09
# 1     1.528844e+09
# ...            ...
# 9710  1.528935e+09
# 9732  1.537099e+09
# 9732  1.537099e+09
# 9732  1.537099e+09
# 9732  1.537099e+09
#
# [2851 rows x 6 columns]

# %%
tag_strings = []
movies = []

for movie, group in tqdm(movies_with_tags.groupby('title')):
    # print(group.tag.head)
    # print(movie.)
    tag_strings.append(' '.join([str(s).replace(' ', '').replace('-', '') for s in group.tag.values]))
    movies.append(movie)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1572.0), HTML(value='')))
# <bound method NDFrame.head of 7075           artistic
# 7075              Funny
# 7075           humorous
# 7075          inspiring
# 7075        intelligent
# 7075             quirky
# 7075            romance
# 7075    Zooey Deschanel
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2554    lawyers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9221      creepy
# 9221    suspense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1940    Shakespeare sort of
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1052      dogs
# 1052    remake
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1549    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5019    terrorism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 905                court
# 905       claustrophobic
# 905      confrontational
# 905              earnest
# 905        good dialogue
# 905     great screenplay
# 905               gritty
# 905         Motivational
# 905    thought-provoking
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7454    stranded
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4939    Mark Ruffalo
# Name: tag, dtype: object>
# <bound method NDFrame.head of 706                                      Hal
# 706                                    space
# 706                                   aliens
# 706                                     apes
# 706                         Arthur C. Clarke
# 706                  artificial intelligence
# 706                              atmospheric
# 706                           cinematography
# 706                                  classic
# 706                                 computer
# 706                         confusing ending
# 706                                cult film
# 706                                     Dull
# 706                                   future
# 706                               futuristic
# 706                             imdb top 250
# 706                              masterpiece
# 706                               meditative
# 706                                    music
# 706                                  mystery
# 706    Oscar (Best Effects - Visual Effects)
# 706                                overrated
# 706                            philosophical
# 706                                 relaxing
# 706                            revolutionary
# 706                                   robots
# 706                                   sci-fi
# 706                 setting:space/space ship
# 706                                     slow
# 706                               slow paced
# 706                               soundtrack
# 706                                    space
# 706                             space travel
# 706                               spacecraft
# 706                          Stanley Kubrick
# 706                        superb soundtrack
# 706                                  surreal
# 706                               technology
# 706                                  tedious
# 706                                   visual
# 706                       visually appealing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4654    DEPRESSING
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4139        crime
# 4139    nightclub
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4408    zombies
# 4408    zombies
# Name: tag, dtype: object>
# <bound method NDFrame.head of 740    fugitive
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6557    Christian Bale
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5972    BEST PICTURE
# 5972         classic
# 5972       hilarious
# 5972    steve carell
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2052       emotional
# 2052          gentle
# 2052    heartwarming
# 2052         lyrical
# 2052      reflective
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2323    In Netflix queue
# 2323           Up series
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3847    books
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1886    Nicolas Cage
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8437    Charlize Theron
# 8437        Liam Neeson
# 8437    Seth MacFarlane
# 8437              witty
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8748     depressing
# 8748    understated
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8740                  film history
# 8740                        poetic
# 8740    representation of children
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3234       android(s)/cyborg(s)
# 3234    artificial intelligence
# 3234                Bittersweet
# 3234           Steven Spielberg
# 3234                     robots
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3831    Nick Hornby
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3300    rape
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4782    Hepburn and Tracy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 355         black comedy
# 355      Christina Ricci
# 355    Christopher Lloyd
# 355          dark comedy
# 355               family
# 355               gothic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1585         black comedy
# 1585      Christina Ricci
# 1585    Christopher Lloyd
# 1585               Family
# 1585               gothic
# 1585               quirky
# Name: tag, dtype: object>
# <bound method NDFrame.head of 303    cross dressing
# 303       men in drag
# 303            remade
# Name: tag, dtype: object>
# <bound method NDFrame.head of 720    swashbuckler
# Name: tag, dtype: object>
# <bound method NDFrame.head of 742    missionary
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5032    Nick and Nora Charles
# Name: tag, dtype: object>
# <bound method NDFrame.head of 356    Edith Wharton
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1209    president
# Name: tag, dtype: object>
# <bound method NDFrame.head of 357    Comedy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2097    aviation
# 2097       spoof
# Name: tag, dtype: object>
# <bound method NDFrame.head of 973            animation
# 973                anime
# 973    visually stunning
# Name: tag, dtype: object>
# <bound method NDFrame.head of 506    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3116    sexuality
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4177    class
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5323    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 789    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 915    aliens
# Name: tag, dtype: object>
# <bound method NDFrame.head of 902          action
# 902          aliens
# 902          horror
# 902          sci-fi
# 902           space
# 902     space craft
# 902    SPACE TRAVEL
# 902        suspense
# 902           space
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2437    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 707    Hollywood
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1420             Huey Long
# 1420      In Netflix queue
# 1420    Robert Penn Warren
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4568     journalism
# 4568      Watergate
# 4568    Deep Throat
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4231    adolescence
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2907            music
# 2907       journalism
# 2907            music
# 2907    Rolling Stone
# Name: tag, dtype: object>
# <bound method NDFrame.head of 926     Mozart
# 926    Salieri
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3622    whimsical
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4190    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3410         Hollywood
# 3410    movie business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6609           corruption
# 6609    Denzel Washington
# 6609                mafia
# 6609      organized crime
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1734    thought-provoking
# 1734               racism
# 1734        edward norton
# 1734            emotional
# 1734             politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2266    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2031            best comedy
# 2031            Chris Klein
# 2031                   dumb
# 2031            Jason Biggs
# 2031              not funny
# 2031             pizza beer
# 2031    Seann William Scott
# 2031                   teen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 10     politics
# 10    president
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4482    cancer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 682    France
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5126    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4415    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2842    court
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8321              comedy
# 8321        Steve Carell
# 8321    stupid but funny
# 8321        will ferrell
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5263       hilarious
# 5263    Steve Carell
# 5263    Will Ferrell
# 5263          stupid
# 5263         awesome
# 5263          comedy
# 5263    Will Ferrell
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3619    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1536                AIDs
# 1536    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5407      mindfuck
# 5407       surreal
# 5407    surrealism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8522    atmospheric
# 8522        bizzare
# 8522          eerie
# 8522      symbolism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4569    pregnancy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2555    college
# 2555       TOGA
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5669    animation
# 5669        anime
# 5669    cyberpunk
# 5669         dark
# 5669       Matrix
# 5669       sci-fi
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1142    Tolstoy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 101    Holocaust
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5127    Anne Boleyn
# Name: tag, dtype: object>
# <bound method NDFrame.head of 930    New York
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5029    Nick and Nora Charles
# Name: tag, dtype: object>
# <bound method NDFrame.head of 691    adultery
# Name: tag, dtype: object>
# <bound method NDFrame.head of 909    Vietnam
# Name: tag, dtype: object>
# <bound method NDFrame.head of 123     moon
# 123     NASA
# 123    space
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2027    spiders
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8005          cia
# 8005     politics
# 8005    Thrilling
# Name: tag, dtype: object>
# <bound method NDFrame.head of 527    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1398    space
# Name: tag, dtype: object>
# <bound method NDFrame.head of 732    race
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9392      beautiful visuals
# 9392               Cerebral
# 9392         cinematography
# 9392    good cinematography
# 9392                  smart
# 9392      thought-provoking
# 9392     visually appealing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 601    aliens
# Name: tag, dtype: object>
# <bound method NDFrame.head of 968    murder
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2127    aliens
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5462    donkey
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2650    1920s
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3107    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7212          bad science
# 7212           futuristic
# 7212       graphic design
# 7212        James Cameron
# 7212             military
# 7212        poor dialogue
# 7212               sci-fi
# 7212     superficial plot
# 7212           unoriginal
# 7212          white guilt
# 7212    beautiful scenery
# 7212       graphic design
# 7212                music
# 7212             politics
# 7212              romance
# 7212    thought-provoking
# 7212             too long
# 7212    visually stunning
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7693       Captain America
# 7693                 silly
# 7693             superhero
# 7693        superhero team
# 7693                   fun
# 7693           great humor
# 7693    visually appealing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8693                 comic book
# 8693                Dr. Strange
# 8693              Great villain
# 8693    Guardians of the Galaxy
# 8693                     Marvel
# 8693                        MCU
# 8693          Robert Downey Jr.
# 8693                     Thanos
# 8693                       Thor
# 8693          Visually stunning
# 8693                       Dark
# 8693                  emotional
# 8693                        Sad
# 8693         Visually appealing
# 8693          Visually stunning
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5738            biopic
# 5738     Howard Hughes
# 5738    movie business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4284    screwball
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8465      atmospheric
# 8465             dark
# 8465     Metaphorical
# 8465    psychological
# Name: tag, dtype: object>
# <bound method NDFrame.head of 32                                        Animal movie
# 32                                                pigs
# 32    villain nonexistent or not needed for good story
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6244              Brad Pitt
# 6244         cate blanchett
# 6244    multiple storylines
# 6244      social commentary
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4572    Food
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4983    space station
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5277    court
# Name: tag, dtype: object>
# <bound method NDFrame.head of 969    time travel
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1486    time travel
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5101    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3720    baseball
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2232    evil children
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3709    movie business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5849    fatherhood
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6694                   heist
# 6694                 robbery
# 6694    small time criminals
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4389    movie business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 120            addiction
# 120               heroin
# 120    Leonardo DiCaprio
# 120        Mark Wahlberg
# Name: tag, dtype: object>
# <bound method NDFrame.head of 509    superhero
# Name: tag, dtype: object>
# <bound method NDFrame.head of 126    superhero
# 126    superhero
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1060    superhero
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8963         action
# 8963         batman
# 8963    ben affleck
# 8963           dark
# 8963      dc comics
# 8963      Gal Gadot
# 8963      superhero
# 8963       superman
# 8963    wonderwoman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4705      based on a book
# 4705               bloody
# 4705               brutal
# 4705        controversial
# 4705             dystopia
# 4705           goretastic
# 4705               satire
# 4705    social commentary
# 4705             survival
# 4705             violence
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5457    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9054    Moving
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7930    Beautiful
# 7930    emotional
# 7930       poetic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 743    crime
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3640    mathematics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 512    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 183    generation X
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5261    generation X
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5560         boring
# 5560    psychedelic
# 5560       symbolic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5361    stage
# Name: tag, dtype: object>
# <bound method NDFrame.head of 991    television
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3833    anti-Semitism
# 3833          Judaism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4262    soccer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1108    mental illness
# 1108          Not Seen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2916    satire
# 2916      Dogs
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4302    gangs
# Name: tag, dtype: object>
# <bound method NDFrame.head of 956    skiing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1382    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2103    children
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3308    twins
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2022    Adam Sandler
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8632    painter
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4796      dreamlike
# 4796    sentimental
# 4796        surreal
# 4796     Tim Burton
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8546           animation
# 8546                kids
# 8546              robots
# 8546           feel-good
# 8546    fun family movie
# 8546          very funny
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2664    business
# 2664    religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1298             Coen Brothers
# 1298              black comedy
# 1298                   bowling
# 1298                   classic
# 1298             coen brothers
# 1298                    comedy
# 1298                     crime
# 1298              Cult classic
# 1298                 cult film
# 1298               dark comedy
# 1298                   deadpan
# 1298                     drugs
# 1298                     funny
# 1298            great dialogue
# 1298          great soundtrack
# 1298           Highly quotable
# 1298              imdb top 250
# 1298              Jeff Bridges
# 1298              John Goodman
# 1298            Julianne Moore
# 1298                kidnapping
# 1298                 marijuana
# 1298     Nudity (Full Frontal)
# 1298           off-beat comedy
# 1298    Philip Seymour Hoffman
# 1298                    quirky
# 1298                    ransom
# 1298                       rug
# 1298                   sarcasm
# 1298                 satirical
# 1298             Steve Buscemi
# 1298                  violence
# Name: tag, dtype: object>
# <bound method NDFrame.head of 757    food
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9162          funny
# 9162    interesting
# 9162          Witty
# Name: tag, dtype: object>
# <bound method NDFrame.head of 983    Hammett
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3309    circus
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3629    time travel
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3363    time travel
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5316    Stand Up
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4642    big wave
# 4642     surfing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2959    ballet
# Name: tag, dtype: object>
# <bound method NDFrame.head of 184                     school
# 184               Adam Sandler
# 184    stop looking at me swan
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4740     birds
# 4740    prison
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1022    birds
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3112    Christmas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 365    horses
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9570             Dystopia
# 9570               future
# 9570          interesting
# 9570             jon hamm
# 9570    thought provoking
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5157     convent
# 5157    religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4762    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3440    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4236    horses
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7456      alter ego
# 7456    atmospheric
# 7456         creepy
# 7456         horror
# 7456      obsession
# 7456        surreal
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1623    vampires
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3764      Great movie
# 3764    Wesley Snipes
# Name: tag, dtype: object>
# <bound method NDFrame.head of 474                     sci-fi
# 474                     robots
# 474                   androids
# 474    artificial intelligence
# 474                atmospheric
# 474                  cyberpunk
# 474                     future
# 474                   mindfuck
# 474             Philip K. Dick
# 474                atmospheric
# 474                  dreamlike
# 474             existentialism
# 474              philosophical
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9604       atmospheric
# 9604         beautiful
# 9604    cinematography
# 9604              dark
# 9604         dreamlike
# 9604    existentialism
# 9604             moody
# 9604     philosophical
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2035    claims to be true
# 2035                video
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2733    dark humor
# 2733     easygoing
# 2733         silly
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6358               Africa
# 6358           corruption
# 6358    Jennifer Connelly
# 6358              justice
# 6358    Leonardo DiCaprio
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2745    Coen Brothers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3620    nightclub
# 3620      singers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4335    teachers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 369          mental illness
# 369    Oscar (Best Actress)
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1541    sexuality
# 1541     suburbia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 921    Saturday Night Live
# Name: tag, dtype: object>
# <bound method NDFrame.head of 877    politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 824        1920s
# 824    gangsters
# Name: tag, dtype: object>
# <bound method NDFrame.head of 106    dating
# Name: tag, dtype: object>
# <bound method NDFrame.head of 933    submarine
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4269    animal movie
# 4269           lions
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2500    remade
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5725    India
# Name: tag, dtype: object>
# <bound method NDFrame.head of 89              crime
# 89    off-beat comedy
# 89             quirky
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6534                        assassin
# 6534    assassin-in-training (scene)
# 6534                       espionage
# 6534                   Robert Ludlum
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4012    violence in america
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6909    childish naivity
# 6909          friendship
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2465    sexuality
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1163    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 97              beautiful scenery
# 97                           epic
# 97                     historical
# 97                  inspirational
# 97                       Medieval
# 97                     mel gibson
# 97    Oscar (Best Cinematography)
# 97                        revenge
# 97                    sword fight
# 97                       Scotland
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2849    court
# Name: tag, dtype: object>
# <bound method NDFrame.head of 684    Capote
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6068    transvestite
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1042    religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 949    POW
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3157    singletons
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2202    adultery
# Name: tag, dtype: object>
# <bound method NDFrame.head of 735      leopard
# 735    screwball
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1667    journalism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5075    show business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5955    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7033              Adrien Brody
# 7033               con artists
# 7033                     funny
# 7033    interesting characters
# 7033              Mark Ruffalo
# 7033              Rachel Weisz
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5957    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4356    religion
# 4356     classic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2011    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1397    avant-garde romantic comedy
# 1397                        elegiac
# 1397                     melancholy
# 1397                         quirky
# 1397                            wry
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6489      based on a play
# 6489    conspiracy theory
# 6489               creepy
# 6489             Insanity
# 6489             paranoia
# 6489                 PTSD
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1757    Pixar
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6836       dark comedy
# 6836         Brad Pitt
# 6836         Coen Bros
# 6836     Coen Brothers
# 6836       dark comedy
# 6836         espionage
# 6836    George Clooney
# 6836    John Malkovich
# 6836            satire
# 6836    twists & turns
# 6836             weird
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1002    crime
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3820    blind
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2654    golf
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5156    military
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5837    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4997    King Arthur
# Name: tag, dtype: object>
# <bound method NDFrame.head of 822    politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3253    race
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1032    lawyer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1031             horror
# 1031     Juliette Lewis
# 1031    Martin Scorsese
# 1031     Robert De Niro
# 1031             remake
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6010    Truman Capote
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5121    swashbuckler
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9301    building a family
# 9301             creative
# 9301              freedom
# 9301         good writing
# 9301        individualism
# 9301      Viggo Mortensen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8274     hostage
# 8274       ocean
# 8274    suspense
# 8274    suspense
# 8274       tense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4363    child abuse
# Name: tag, dtype: object>
# <bound method NDFrame.head of 375    Al Pacino
# 375     gangster
# 375        mafia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1033     high school
# 1033            prom
# 1033    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 694    start of a beautiful friendship
# Name: tag, dtype: object>
# <bound method NDFrame.head of 15    Mafia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4996    sexuality
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5686    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6667       abstract
# 6667           dark
# 6667    psychedelic
# 6667        surreal
# Name: tag, dtype: object>
# <bound method NDFrame.head of 744    Tennessee Williams
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2093    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4159                crime
# 4159             cheating
# 4159          intelligent
# 4159    Leonardo DiCaprio
# 4159                 lies
# 4159                smart
# 4159            Tom Hanks
# 4159       twists & turns
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3102    homeless
# 3102    New York
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1762    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1759    South America
# Name: tag, dtype: object>
# <bound method NDFrame.head of 648    seen at the cinema
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7565    Comedy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 764    death penalty
# 764     John Grisham
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6883    emotional
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4976              biopic
# 4976    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 693    heist
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1434    Olympics
# 1434      sports
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5735    roald dahl
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4161     court
# 4161      jazz
# 4161    murder
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1386    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1720    death penalty
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1583    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1926    evil children
# Name: tag, dtype: object>
# <bound method NDFrame.head of 951    incest
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4037    In Netflix queue
# 4037             Judaism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1894    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2110    Christmas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1823    christmas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6751          fantasy
# 6751             lion
# 6751           narnia
# 6751    Tilda Swinton
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6075    C.S. Lewis
# Name: tag, dtype: object>
# <bound method NDFrame.head of 780    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5907    boksdrama
# 5907       boxing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4353    movies
# Name: tag, dtype: object>
# <bound method NDFrame.head of 189    Ireland
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2481    big top
# 2481     circus
# Name: tag, dtype: object>
# <bound method NDFrame.head of 705    Rosebud
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2482    blind
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4176    multiple storylines
# 4176             true story
# 4176                  crime
# 4176            photography
# 4176               violence
# 4176               not seen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 28    kidnapping
# Name: tag, dtype: object>
# <bound method NDFrame.head of 307    Tom Clancy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 190             cynical
# 190           hilarious
# 190    independent film
# 190              quirky
# 190               witty
# 190        generation X
# Name: tag, dtype: object>
# <bound method NDFrame.head of 308    John Grisham
# Name: tag, dtype: object>
# <bound method NDFrame.head of 907    brainwashing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 35            chick flick
# 35                  funny
# 35              Paul Rudd
# 35               quotable
# 35    seen more than once
# 35                   Emma
# 35            Jane Austen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3537    Loretta Lynn
# Name: tag, dtype: object>
# <bound method NDFrame.head of 590    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4807    Civil War
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5148    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2587    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5336    alcoholism
# 5336      marriage
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4590    atmospheric
# 4590          bleak
# 4590     disturbing
# 4590         gritty
# 4590          harsh
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2783    Vietnam
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3317        Africa
# 3317    immigrants
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2308    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4169    television
# Name: tag, dtype: object>
# <bound method NDFrame.head of 133    Michael Crichton
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5981      Africa
# 5981    business
# 5981    politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5400    journalism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2789    spying
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1949    southern US
# Name: tag, dtype: object>
# <bound method NDFrame.head of 975    prison
# Name: tag, dtype: object>
# <bound method NDFrame.head of 21    serial killer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6965         claymation
# 6965             creepy
# 6965               dark
# 6965    dark fairy tale
# 6965            Surreal
# 6965         Tim Burton
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6005                                       gothic
# 6005                         helena bonham carter
# 6005                                  Johnny Depp
# 6005                                   Tim Burton
# 6005                           visually appealing
# 6005                                    animation
# 6005    06 Oscar Nominated Best Movie - Animation
# Name: tag, dtype: object>
# <bound method NDFrame.head of 309    interracial romance
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5353    Oscar (Best Actress)
# Name: tag, dtype: object>
# <bound method NDFrame.head of 545    Gulf War
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4298    amazing artwork
# 4298              anime
# 4298             sci-fi
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5885    racism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2562    aardman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 134    submarine
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1858    Australia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1859    Australia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8123    animation
# 8123        funny
# 8123    stone age
# Name: tag, dtype: object>
# <bound method NDFrame.head of 814    anti-Semitism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3320    New York
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2983           china
# 2983    martial arts
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1051    Arthur Miller
# Name: tag, dtype: object>
# <bound method NDFrame.head of 135    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2417    a dingo ate my baby
# 2417              Australia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 36    In Netflix queue
# 36        South Africa
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1582    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2457    figure skating
# Name: tag, dtype: object>
# <bound method NDFrame.head of 976    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6208            adventure
# 6208        Audrey Tautou
# 6208    conspiracy theory
# 6208              Mystery
# 6208                Paris
# 6208            Tom Hanks
# 6208        treasure hunt
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8290           Jared Leto
# 8290    social commentary
# 8290            uplifting
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2915    blindness
# 2915      factory
# Name: tag, dtype: object>
# <bound method NDFrame.head of 508    American Indians
# 508    Native Americans
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1495    adultery
# Name: tag, dtype: object>
# <bound method NDFrame.head of 30    high school
# 30        teacher
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5311    Australia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4229            bad
# 4229    Ben Affleck
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1305    amnesia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5060                   Amtrak
# 5060                 Homeless
# 5060              independent
# 5060                 New York
# 5060    Sundance award winner
# 5060                    Train
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7768           Anne Hathaway
# 7768          Christian Bale
# 7768       Christopher Nolan
# 7768              comic book
# 7768            great ending
# 7768          Morgan Freeman
# 7768    political commentary
# 7768               superhero
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6710    psychology
# 6710     superhero
# 6710          dark
# 6710        gritty
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4835    amnesia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4739    terminal illness
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5089    remade
# Name: tag, dtype: object>
# <bound method NDFrame.head of 383    President
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5132    assassination
# Name: tag, dtype: object>
# <bound method NDFrame.head of 952    aliens
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3168    alcoholism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2297    memory
# 2297     music
# Name: tag, dtype: object>
# <bound method NDFrame.head of 33    death penalty
# 33              Nun
# Name: tag, dtype: object>
# <bound method NDFrame.head of 945     highschool
# 945    High School
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1579    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9709      Josh Brolin
# 9709    Ryan Reynolds
# 9709          sarcasm
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5224    Ireland
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2445    plastic surgery
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4329     1970s
# 4329    movies
# Name: tag, dtype: object>
# <bound method NDFrame.head of 962    Vietnam
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3641    racism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6682     Rachel Weisz
# 6682    Ryan Reynolds
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6326    the catholic church is the most corrupt organi...
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2156    river
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6315         way too long
# 6315    Leonardo DiCaprio
# 6315             suspense
# 6315         twist ending
# 6315       undercover cop
# 6315          atmospheric
# 6315       Jack Nicholson
# 6315    Leonardo DiCaprio
# 6315      Martin Scorsese
# 6315             suspense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4666    Hepburn and Tracy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3579    ghosts
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4661    Amish
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5945    Rob Zombie
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4871      priest
# 4871    religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1971    comic book
# Name: tag, dtype: object>
# <bound method NDFrame.head of 827    dance
# 827    music
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4436    immigration
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7090    intelligent sci-fi
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8347    anti-intellectual
# 8347          bad writing
# 8347             dystopia
# 8347          new society
# 8347           plot holes
# 8347          predictable
# 8347                scifi
# 8347        unintelligent
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3219    Holocaust
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5185    divorce
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8063                action
# 8063       Christoph Waltz
# 8063                 funny
# 8063       good soundtrack
# 8063    Great performances
# 8063                Humour
# 8063     Leonardo DiCaprio
# 8063     Quentin Tarantino
# 8063     Samuel L. Jackson
# 8063            Soundtrack
# 8063               western
# 8063            Soundtrack
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2558                  racism
# 2558    great cinematography
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8697    visually appealing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4182    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2302            irreverent
# 2302    jay and silent bob
# 2302           Kevin Smith
# 2302                satire
# 2302              religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4916    Grace
# Name: tag, dtype: object>
# <bound method NDFrame.head of 196    Stephen King
# Name: tag, dtype: object>
# <bound method NDFrame.head of 191    mental illness
# 191        psychology
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9359    intense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1124    Mafia
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3562          atmospheric
# 3562            cult film
# 3562            dreamlike
# 3562        hallucinatory
# 3562        psychological
# 3562              surreal
# 3562          time travel
# 3562      jake gyllenhaal
# 3562          time travel
# 3562            dreamlike
# 3562        hallucinatory
# 3562       mental illness
# 3562           psychology
# 3562    social commentary
# 3562                 teen
# 3562    thought-provoking
# 3562          atmospheric
# 3562             cerebral
# 3562            dreamlike
# 3562            enigmatic
# 3562        hallucinatory
# 3562       mental illness
# 3562             mindfuck
# 3562           philosophy
# 3562        psychological
# 3562               quirky
# 3562              surreal
# 3562    thought-provoking
# 3562                weird
# Name: tag, dtype: object>
# <bound method NDFrame.head of 832           1960s
# 832    Jim Morrison
# 832           music
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2568    Insurance
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4471    Othello
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3943    homeless
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4352      Ewan McGregor
# 4352    Renee Zellweger
# 4352              retro
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6985            joss whedon
# 6985         Nathan Fillion
# 6985    Neil Patrick Harris
# 6985                 parody
# Name: tag, dtype: object>
# <bound method NDFrame.head of 602          dark comedy
# 602          Atomic bomb
# 602         black comedy
# 602          dark comedy
# 602               satire
# 602    purity of essence
# 602         Slim Pickens
# 602         black comedy
# 602          dark comedy
# 602               Quirky
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1387    generation X
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5175    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1439    rasicm
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2999    bad
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5478    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5969        Animal movie
# 5969    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 786    Disney
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4528    vertriloquism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9571    brilliant
# 9571    inspiring
# 9571        tense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 836    aliens
# Name: tag, dtype: object>
# <bound method NDFrame.head of 198    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 201    movie business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5123    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1704    freaks
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4627            adolescence
# 4627    violence in america
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1721    freaks
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4641    christmas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6607    Favelas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1741    England
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3115    preacher
# 3115    religion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 650    Jane Austen
# Name: tag, dtype: object>
# <bound method NDFrame.head of 882    Italy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2359    Graham Greene
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3138       Ed Harris
# 3138        Jude Law
# 3138    Rachel Weisz
# 3138          sniper
# 3138    World War II
# Name: tag, dtype: object>
# <bound method NDFrame.head of 886    adultery
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3800    World War II
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5881    business
# 5881       money
# 5881     scandal
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2738    In Netflix queue
# 2738           art house
# 2738         Atmospheric
# 2738              creepy
# 2738             cryptic
# 2738                dark
# 2738          disturbing
# 2738           dreamlike
# 2738           enigmatic
# 2738           fucked up
# 2738            gruesome
# 2738       hallucinatory
# 2738              Insane
# 2738            paranoid
# 2738             strange
# 2738             surreal
# 2738               weird
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2546       scandal
# 2546    true story
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4909    alternate reality
# 4909               memory
# 4909    thought-provoking
# 4909           jim carrey
# 4909               memory
# 4909            cult film
# 4909          imagination
# 4909           Jim Carrey
# 4909                 love
# 4909              surreal
# 4909             arthouse
# 4909             artistic
# 4909          atmospheric
# 4909            beautiful
# 4909          bittersweet
# 4909            colourful
# 4909               comedy
# 4909            dreamlike
# 4909            emotional
# 4909            feel-good
# 4909           happpiness
# 4909               humane
# 4909           insightful
# 4909          intelligent
# 4909               lovely
# 4909           melancholy
# 4909         mind-bending
# 4909           philosophy
# 4909               quirky
# 4909      quirky romantic
# 4909             romantic
# 4909              surreal
# 4909           surrealism
# 4909    thought-provoking
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4271       Holocaust
# 4271    World War II
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1328    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9256    80's
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5987    In Netflix queue
# Name: tag, dtype: object>
# ...
# Name: tag, dtype: object>
# <bound method NDFrame.head of 908    Harper Lee
# 908        racism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 284    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5248    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1425    British
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9692                adventure
# 9692          Alicia Vikander
# 9692    video game adaptation
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3229    men in drag
# Name: tag, dtype: object>
# <bound method NDFrame.head of 839    predictable
# 839           Navy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 725    Astaire and Rogers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4853    mountain climbing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7279      surreal
# 7279    whimsical
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7415                     crime
# 7415                       FBI
# 7415                   romance
# 7415    too much love interest
# Name: tag, dtype: object>
# <bound method NDFrame.head of 0    pixar
# 0    pixar
# 0      fun
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2355    animation
# 2355       Disney
# 2355        funny
# 2355     original
# 2355        Pixar
# 2355       sequel
# 2355    Tom Hanks
# 2355        Pixar
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2292          class
# 2292    Dan Aykroyd
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3016                 drugs
# 3016    based on a TV show
# Name: tag, dtype: object>
# <bound method NDFrame.head of 613    based on a book
# 613        dark comedy
# 613           narrated
# 613         drug abuse
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7064                                    bad plot
# 7064                                 Michael Bay
# 7064                        needed more autobots
# 7064                                  plot holes
# 7064                                  ridiculous
# 7064                                Shia LaBeouf
# 7064    stop using useless characters for filler
# Name: tag, dtype: object>
# <bound method NDFrame.head of 953    Cold
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2021    Star Trek
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4558    biking
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7484        action choreography
# 7484    Horrid characterisation
# 7484      Poor plot development
# 7484                     sequel
# 7484                 soundtrack
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7483      atmospheric
# 7483    Coen Brothers
# 7483     Jeff Bridges
# 7483       Matt Damon
# 7483      predictable
# Name: tag, dtype: object>
# <bound method NDFrame.head of 337    spies
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3660    Ghost
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1267    TV
# Name: tag, dtype: object>
# <bound method NDFrame.head of 577    Veterinarian
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7500    black comedy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4649    music business
# 4649               rap
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3433    dogs
# Name: tag, dtype: object>
# <bound method NDFrame.head of 676    Shakespeare
# Name: tag, dtype: object>
# <bound method NDFrame.head of 31         time travel
# 31         time travel
# 31           Brad Pitt
# 31        Bruce Willis
# 31            mindfuck
# 31    Post apocalyptic
# 31    post-apocalyptic
# 31              remake
# 31         time travel
# 31        twist ending
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5824    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6905    audience intelligence underestimated
# 6905                                  boring
# 6905                             chick flick
# 6905                               overrated
# 6905                              Teen movie
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5687    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3357    twins
# Name: tag, dtype: object>
# <bound method NDFrame.head of 594    Disaster
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8501    bittersweet
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2947    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3434    television
# Name: tag, dtype: object>
# <bound method NDFrame.head of 168    Made me cry
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2982                  superhero
# 2982                atmospheric
# 2982                     comics
# 2982    father-son relationship
# 2982                   mindfuck
# 2982                     unique
# 2982                atmospheric
# 2982                     somber
# Name: tag, dtype: object>
# <bound method NDFrame.head of 965    revenge
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1645       Capone
# 1645    gangsters
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4635    India
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7039             adventure
# 7039     Bechdel Test:Fail
# 7039               cartoon
# 7039              children
# 7039    computer animation
# 7039               divorce
# 7039                  dogs
# 7039                dreams
# 7039                 Pixar
# 7039           bittersweet
# 7039             emotional
# 7039         heartbreaking
# 7039              touching
# Name: tag, dtype: object>
# <bound method NDFrame.head of 115    journalism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7642               britpop
# 7642    indie record label
# 7642                 music
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8084          artistic
# 8084             artsy
# 8084       atmospheric
# 8084         Beautiful
# 8084         dreamlike
# 8084    existentialism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 46        mindfuck
# 46        suspense
# 46        thriller
# 46          tricky
# 46    twist ending
# 46           heist
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3517    remake
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3353    kidnapping
# 3353        remade
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5367    abortion
# Name: tag, dtype: object>
# <bound method NDFrame.head of 685             falling
# 685    Alfred Hitchcock
# 685         Atmospheric
# 685        imdb top 250
# 685       James Stewart
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1788    dark comedy
# 1788     dark humor
# Name: tag, dtype: object>
# <bound method NDFrame.head of 639    based on a TV show
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6814    threesome
# Name: tag, dtype: object>
# <bound method NDFrame.head of 821    cross dressing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1925    evil children
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5301           Atmospheric
# 5301       good soundtrack
# 5301    M. Night Shyamalan
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2658    sofia coppola
# 2658            1970s
# 2658          suicide
# Name: tag, dtype: object>
# <bound method NDFrame.head of 296    serial killer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6100    love
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2525    Peace Corp
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6772    last man on earth
# 6772           love story
# 6772     Post apocalyptic
# 6772    social commentary
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4505    FBI
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4988    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4490    blindness
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1113    mockumentary
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5996    restaurant
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6063    Johnny Cash
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4374    Olympics
# 4374       Tokyo
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2992    business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6015    06 Oscar Nominated Best Movie - Animation
# 6015                                      Aardman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 599    Aardman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 585    Aardman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 868    Aardman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 487    politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2001    classic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4672    Cold War
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7697    Boxing story
# 7697             MMA
# 7697       Tom Hardy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1241    Henry James
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4952    World War II
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1740    football
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1596    atmospheric
# 1596      beautiful
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5084    politics
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4706    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5938    stiller
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1319    1980s
# Name: tag, dtype: object>
# <bound method NDFrame.head of 489    adolescence
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1424    Gangs
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4366    Girl Power
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2649    show business
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8253    daniel radcliffe
# 8253           zoe kazan
# Name: tag, dtype: object>
# <bound method NDFrame.head of 295    mental illness
# Name: tag, dtype: object>
# <bound method NDFrame.head of 415    biopic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1005    New York
# Name: tag, dtype: object>
# <bound method NDFrame.head of 867              boxing
# 867    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 338    alcoholism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 297    coma
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8466          passion
# 8466    psychological
# 8466         suspense
# 8466             jazz
# 8466            music
# 8466            tense
# 8466    inspirational
# 8466        inspiring
# 8466          intense
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2737    Christmas
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2450    basketball
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2250    live action/animation
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9234        Cambodia
# 9234           crime
# 9234    human rights
# 9234          murder
# 9234      procedural
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1088    Conan
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5993    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3100    death penalty
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5848      birds
# 5848    parrots
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8575              black comedy
# 8575               dark comedy
# 8575                dark humor
# 8575                    ironic
# 8575    multiple short stories
# 8575             short stories
# Name: tag, dtype: object>
# <bound method NDFrame.head of 809    Amazing Cinematography
# 809         Leonardo DiCaprio
# 809               shakespeare
# 809          updated classics
# 809               Shakespeare
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4311    birds
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1268    Henry James
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4967    cancer
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3043    psychopaths
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1259    Amish
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3644    Agatha Christie
# 3644              court
# Name: tag, dtype: object>
# <bound method NDFrame.head of 701    Dorothy
# 701       Toto
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8305                drugs
# 8305    Leonardo DiCaprio
# 8305      Martin Scorsese
# 8305         Stock Market
# 8305          Wall Street
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4747    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4971    Hepburn and Tracy
# 4971             marriage
# Name: tag, dtype: object>
# <bound method NDFrame.head of 708    divorce
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2488    writing
# Name: tag, dtype: object>
# <bound method NDFrame.head of 321           Holocaust
# 321    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5741    child abuse
# Name: tag, dtype: object>
# <bound method NDFrame.head of 557    India
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4070    teenagers
# Name: tag, dtype: object>
# <bound method NDFrame.head of 9170    Existential
# 9170        surreal
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1391    conspiracy
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2836          action
# 2836      comic book
# 2836    hugh jackman
# 2836          marvel
# 2836       superhero
# 2836       superhero
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7016             comic book
# 7016               bad plot
# 7016             comic book
# 7016           hugh jackman
# 7016          Ryan Reynolds
# 7016    too many characters
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6209     Halle Berry
# 6209    Hugh Jackman
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4334    Jean Grey
# 4334      Magneto
# 4334        Rogue
# 4334    superhero
# 4334    Wolverine
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4603    biopic
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2196    Academy award (Best Supporting Actress)
# 2196                                  Indonesia
# 2196                                 journalism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3970    Animal movie
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3648    cross dressing
# 3648           Judaism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2283    samurai
# Name: tag, dtype: object>
# <bound method NDFrame.head of 2971    family
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4414    fugitive
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4634    Rita Hayworth can dance!
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1824    e-mail
# 1824    remake
# Name: tag, dtype: object>
# <bound method NDFrame.head of 977    spoof
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3897    In Netflix queue
# Name: tag, dtype: object>
# <bound method NDFrame.head of 6865      Seth Rogen
# 6865    Sexual Humor
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5806    marriage
# Name: tag, dtype: object>
# <bound method NDFrame.head of 5061    psychology
# Name: tag, dtype: object>
# <bound method NDFrame.head of 8056            Afghanistan
# 8056    American propaganda
# 8056          assassination
# 8056               military
# 8056              terrorism
# Name: tag, dtype: object>
# <bound method NDFrame.head of 7154        Bill Murray
# 7154        dark comedy
# 7154         Emma Stone
# 7154              funny
# 7154    Jesse Eisenberg
# 7154    Woody Harrelson
# Name: tag, dtype: object>
# <bound method NDFrame.head of 3525            ben stiller
# 3525                 comedy
# 3525            David Bowie
# 3525                  goofy
# 3525    mindless one liners
# 3525           Will Ferrell
# Name: tag, dtype: object>
# <bound method NDFrame.head of 4114    Africa
# Name: tag, dtype: object>
# <bound method NDFrame.head of 1961    virtual reality
# Name: tag, dtype: object>

# %%
tag_strings[:5]

# %%
movies_with_tags.head()

# %%
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(tag_strings)

# %%
tfidf_transformer = TfidfTransformer()
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

# %%
neigh = NearestNeighbors(n_neighbors=10, n_jobs=-1, metric='manhattan') 
neigh.fit(X_train_tfidf)

# %%
for i in range(len(movies)):
    if 'Magnolia (1999)' == movies[i]:
        print(i)

# %%
tag_strings[822]

# %%
test = change_string('pixar pixar fun')

predict = count_vect.transform([test])
X_tfidf2 = tfidf_transformer.transform(predict)

res = neigh.kneighbors(X_tfidf2, return_distance=True)

# %%
res

# %%
for i in res[1][0]:
    print(movies[i])
